# %%
import json
import pandas as pd
import numpy as np
import datetime
from airflow.providers.postgres.hooks.postgres import PostgresHook
from airflow.providers.mysql.hooks.mysql import MySqlHook
import seaborn as sns
warehouse_hook = PostgresHook(postgres_conn_id='rds_afsg_ds_prod_postgresql_dwh', schema='afsg_ds_prod_postgresql_dwh')
mifos_hook = MySqlHook(mysql_conn_id='mifos_db', schema='mifostenant-safaricom')
airflow_hook = MySqlHook(mysql_conn_id='mysql_airflow', schema='bloom_pipeline')
middleware_hook = PostgresHook(postgres_conn_id='asante_mfs_middleware', schema='asante_datawarehouse')
jubilee_hook = MySqlHook(mysql_conn_id='mifos_db', schema='mifostenant-jubilee')
solv_hook = MySqlHook(mysql_conn_id='solv_ke', schema='solvke_staging')
# Out:
# /tmp/ipykernel_4818/1888061882.py:8 DeprecationWarning: The "schema" arg has been renamed to "database" as it contained the database name.Please use "database" to set the database name.
# /tmp/ipykernel_4818/1888061882.py:11 DeprecationWarning: The "schema" arg has been renamed to "database" as it contained the database name.Please use "database" to set the database name.

# %%
warehouse_clients = warehouse_hook.get_pandas_df(
    sql="""select mifos_id from bloomlive.client_dimension where bloom_version = '2'"""
)
mifos_clients = mifos_hook.get_pandas_df(
    sql="""select id from `mifostenant-safaricom`.m_client"""
)
# Out:
# [2023-06-13 11:10:46,831] {base.py:73} INFO - Using connection ID 'rds_afsg_ds_prod_postgresql_dwh' for task execution.
# /home/henrykuria/airflow_venv/lib/python3.10/site-packages/pandas/io/sql.py:761 UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
# [2023-06-13 11:10:55,628] {base.py:73} INFO - Using connection ID 'mifos_db' for task execution.
# /home/henrykuria/airflow_venv/lib/python3.10/site-packages/pandas/io/sql.py:761 UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy

# %%
xtra = warehouse_clients[~warehouse_clients['mifos_id'].isin(mifos_clients['id'].tolist())]

# %%
warehouse_hook.run(sql="""delete from bloomlive.client_dimension where mifos_id in %(mi)s and bloom_version = '2'""", parameters={'mi': tuple(xtra['mifos_id'].tolist())})
# Out:
#         mifos_id
# 2811      204016
# 5037      204093
# 13179     204269
# 13742     204271
# 13771     204272
# ...          ...
# 188148    204119
# 188149    204106
# 188152    203925
# 188154    204121
# 188155    204123
#
# [632 rows x 1 columns]

# %%
warehouse_loans = warehouse_hook.get_pandas_df(
    sql="""
        select loan_mifos_id, bloom_version, client_mifos_id from bloomlive.loans_fact_table_materialized_summary_view
    """
)
mifos_loans = pd.concat([
    mifos_hook.get_pandas_df(
        sql="""select id, client_id, 2 as "bloom_version" from `mifostenant-safaricom`.m_loan"""
    ), mifos_hook.get_pandas_df(
        sql="""select id, client_id, 1 as "bloom_version" from `mifostenant-default`.m_loan"""
    )
])
merged = warehouse_loans.merge(mifos_loans,
    left_on=['loan_mifos_id', 'bloom_version'],
    right_on=['id', 'bloom_version'],
    how='left'
)
merged[merged['client_mifos_id'] != merged['client_id']]
# Out:
# [2023-05-26 10:29:07,821] {base.py:73} INFO - Using connection ID 'rds_afsg_ds_prod_postgresql_dwh' for task execution.
# /home/henrykuria/airflow_venv/lib/python3.10/site-packages/pandas/io/sql.py:761 UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
# [2023-05-26 10:30:07,609] {base.py:73} INFO - Using connection ID 'mifos_db' for task execution.
# /home/henrykuria/airflow_venv/lib/python3.10/site-packages/pandas/io/sql.py:761 UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
# [2023-05-26 10:30:39,335] {base.py:73} INFO - Using connection ID 'mifos_db' for task execution.
# /home/henrykuria/airflow_venv/lib/python3.10/site-packages/pandas/io/sql.py:761 UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
# Empty DataFrame
# Columns: [loan_mifos_id, bloom_version, client_mifos_id, id, client_id]
# Index: []

# %%
merged[merged['client_mifos_id'] != merged['client_id']]
# Out:
# Empty DataFrame
# Columns: [loan_mifos_id, bloom_version, client_mifos_id, id, client_id]
# Index: []

# %%
merged[merged['client_mifos_id'] == merged['client_id']].shape
# Out:
# (529319, 5)

# %%
mifos_loans.shape
# Out:
# (529349, 3)

# %%
merged = warehouse_loans.merge(
    mifos_loans,
    left_on=['loan_mifos_id', 'bloom_version'],
    right_on=['id', 'bloom_version'],
    how='left'
)
merged
# Out:
#         loan_mifos_id  bloom_version  client_mifos_id      id  client_id
# 0               57385            1.0            31573   57385      31573
# 1               57462            1.0            38267   57462      38267
# 2               57972            1.0            11244   57972      11244
# 3               59101            1.0            30524   59101      30524
# 4               60311            1.0            25647   60311      25647
# ...               ...            ...              ...     ...        ...
# 529314         309985            2.0           128302  309985     128302
# 529315         308804            2.0            21048  308804      21048
# 529316         308933            2.0           102650  308933     102650
# 529317         309817            2.0            35928  309817      35928
# 529318         310047            2.0            99060  310047      99060
#
# [529319 rows x 5 columns]

# %%
merged[merged['id'].isna()]
# Out:
# Empty DataFrame
# Columns: [loan_mifos_id, bloom_version, client_mifos_id, id, client_id]
# Index: []

# %%
warehouse_loans[warehouse_loans.duplicated(subset=['loan_mifos_id', 'bloom_version'])]
# Out:
# Empty DataFrame
# Columns: [loan_mifos_id, bloom_version, client_mifos_id]
# Index: []

# %%
merged[merged['client_mifos_id'] != merged['client_id']]
# Out:
# Empty DataFrame
# Columns: [loan_mifos_id, bloom_version, client_mifos_id, id, client_id]
# Index: []

# %%
affected_records = warehouse_hook.get_pandas_df(
    sql="""
        select lft.surrogate_id as lft_surrogate_id, lft.client_key, loan_mifos_id, lftmsv.bloom_version, client_surrogate_id
        from bloomlive.loans_fact_table_materialized_summary_view lftmsv
        inner join (
            SELECT DISTINCT mifos_id, bloom_version
            FROM bloomlive.loans_fact_table
            GROUP BY mifos_id, bloom_version
            HAVING COUNT(DISTINCT client_key) > 1
        ) dups on lftmsv.loan_mifos_id = dups.mifos_id and lftmsv.bloom_version = dups.bloom_version
        inner join bloomlive.loans_fact_table lft on lftmsv.loan_mifos_id = lft.mifos_id and lftmsv.bloom_version = lft.bloom_version
        and lft.client_key != lftmsv.client_surrogate_id
    """
)
# Out:
# [2023-05-29 02:48:01,279] {base.py:73} INFO - Using connection ID 'rds_afsg_ds_prod_postgresql_dwh' for task execution.
# /home/henrykuria/airflow_venv/lib/python3.10/site-packages/pandas/io/sql.py:761 UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy

# %%
affected_records.head()
# Out:
#    lft_surrogate_id  client_key  loan_mifos_id  bloom_version  \
# 0           1173636      102092           3700            2.0
# 1           1168939      102092           3700            2.0
# 2           1170115      102092           3700            2.0
# 3           1185791      102092           3700            2.0
# 4           1174920      102092           3700            2.0
#
#    client_surrogate_id
# 0               114196
# 1               114196
# 2               114196
# 3               114196
# 4               114196

# %%
updates = []
for i, r in affected_records.iterrows():
    updates.append(f"update bloomlive.loans_fact_table set client_key = {r['client_surrogate_id']} where surrogate_id = {r['lft_surrogate_id']}")

# %%
warehouse_hook.run(sql=updates)
# Out:
# [2023-05-29 02:51:15,977] {base.py:73} INFO - Using connection ID 'rds_afsg_ds_prod_postgresql_dwh' for task execution.
# [2023-05-29 02:51:18,740] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1173636.0, parameters: None
# [2023-05-29 02:51:20,072] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:20,078] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1168939.0, parameters: None
# [2023-05-29 02:51:21,096] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:21,098] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1170115.0, parameters: None
# [2023-05-29 02:51:22,099] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:22,101] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1185791.0, parameters: None
# [2023-05-29 02:51:23,106] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:23,109] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1174920.0, parameters: None
# [2023-05-29 02:51:24,167] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:24,171] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1179715.0, parameters: None
# [2023-05-29 02:51:25,192] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:25,195] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1172453.0, parameters: None
# [2023-05-29 02:51:26,204] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:26,206] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1178722.0, parameters: None
# [2023-05-29 02:51:27,240] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:27,244] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1181759.0, parameters: None
# [2023-05-29 02:51:28,263] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:28,265] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1176120.0, parameters: None
# [2023-05-29 02:51:29,365] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:29,367] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1162377.0, parameters: None
# [2023-05-29 02:51:30,413] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:30,415] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1184151.0, parameters: None
# [2023-05-29 02:51:31,438] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:31,443] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1177283.0, parameters: None
# [2023-05-29 02:51:32,429] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:32,432] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1171280.0, parameters: None
# [2023-05-29 02:51:33,419] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:33,422] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113786.0 where surrogate_id = 1176119.0, parameters: None
# [2023-05-29 02:51:34,509] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:34,512] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113786.0 where surrogate_id = 1172452.0, parameters: None
# [2023-05-29 02:51:35,533] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:35,537] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113786.0 where surrogate_id = 1162376.0, parameters: None
# [2023-05-29 02:51:36,558] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:36,561] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113786.0 where surrogate_id = 1177282.0, parameters: None
# [2023-05-29 02:51:37,557] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:37,560] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113786.0 where surrogate_id = 1174919.0, parameters: None
# [2023-05-29 02:51:38,556] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:38,560] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113786.0 where surrogate_id = 1173635.0, parameters: None
# [2023-05-29 02:51:39,637] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:39,639] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113786.0 where surrogate_id = 1171279.0, parameters: None
# [2023-05-29 02:51:40,653] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:40,656] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113786.0 where surrogate_id = 1170114.0, parameters: None
# [2023-05-29 02:51:41,655] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:41,658] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113786.0 where surrogate_id = 1178721.0, parameters: None
# [2023-05-29 02:51:42,702] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:42,706] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113786.0 where surrogate_id = 1168938.0, parameters: None
# [2023-05-29 02:51:43,759] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:43,763] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113786.0 where surrogate_id = 1181758.0, parameters: None
# [2023-05-29 02:51:44,782] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:44,785] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113786.0 where surrogate_id = 1179714.0, parameters: None
# [2023-05-29 02:51:45,876] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:45,879] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1162379.0, parameters: None
# [2023-05-29 02:51:47,002] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51:47,004] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1170117.0, parameters: None
# [2023-05-29 02:51:48,014] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:51
{sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:12,387] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 175059.0 where surrogate_id = 3658628.0, parameters: None
# [2023-05-29 02:53:13,431] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:13,433] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 175059.0 where surrogate_id = 3745968.0, parameters: None
# [2023-05-29 02:53:15,353] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:15,355] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 175059.0 where surrogate_id = 3299780.0, parameters: None
# [2023-05-29 02:53:16,345] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:16,347] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 175059.0 where surrogate_id = 3421570.0, parameters: None
# [2023-05-29 02:53:17,358] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:17,361] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 175059.0 where surrogate_id = 3781340.0, parameters: None
# [2023-05-29 02:53:18,362] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:18,365] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 175059.0 where surrogate_id = 3696728.0, parameters: None
# [2023-05-29 02:53:19,361] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:19,363] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 175059.0 where surrogate_id = 3247462.0, parameters: None
# [2023-05-29 02:53:20,391] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:20,394] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 175059.0 where surrogate_id = 3607896.0, parameters: None
# [2023-05-29 02:53:21,403] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:21,405] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 175059.0 where surrogate_id = 3583001.0, parameters: None
# [2023-05-29 02:53:22,405] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:22,406] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 175059.0 where surrogate_id = 3737874.0, parameters: None
# [2023-05-29 02:53:23,396] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:23,398] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114203.0 where surrogate_id = 1164776.0, parameters: None
# [2023-05-29 02:53:24,416] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:24,417] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114121.0 where surrogate_id = 1165031.0, parameters: None
# [2023-05-29 02:53:25,409] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:25,412] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114108.0 where surrogate_id = 1168484.0, parameters: None
# [2023-05-29 02:53:26,405] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:26,410] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114145.0 where surrogate_id = 1178007.0, parameters: None
# [2023-05-29 02:53:27,456] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:27,459] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114145.0 where surrogate_id = 1166237.0, parameters: None
# [2023-05-29 02:53:28,453] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:28,455] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114136.0 where surrogate_id = 1163655.0, parameters: None
# [2023-05-29 02:53:29,469] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:29,471] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113759.0 where surrogate_id = 1162974.0, parameters: None
# [2023-05-29 02:53:31,320] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:31,323] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114169.0 where surrogate_id = 1165537.0, parameters: None
# [2023-05-29 02:53:32,378] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:32,381] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114142.0 where surrogate_id = 1173576.0, parameters: None
# [2023-05-29 02:53:33,366] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:33,367] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113786.0 where surrogate_id = 1163479.0, parameters: None
# [2023-05-29 02:53:34,369] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:34,370] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114116.0 where surrogate_id = 1162858.0, parameters: None
# [2023-05-29 02:53:35,375] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:35,377] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113260.0 where surrogate_id = 1162546.0, parameters: None
# [2023-05-29 02:53:36,382] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:36,385] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113761.0 where surrogate_id = 1163071.0, parameters: None
# [2023-05-29 02:53:37,398] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:37,400] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114102.0 where surrogate_id = 1164991.0, parameters: None
# [2023-05-29 02:53:38,400] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:38,401] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 136465.0 where surrogate_id = 2504969.0, parameters: None
# [2023-05-29 02:53:39,397] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:39,399] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 136465.0 where surrogate_id = 2501882.0, parameters: None
# [2023-05-29 02:53:40,397] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:40,400] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 136465.0 where surrogate_id = 2471172.0, parameters: None
# [2023-05-29 02:53:41,408] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:41,411] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 137634.0 where surrogate_id = 2501851.0, parameters: None
# [2023-05-29 02:53:42,509] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:42,514] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 137634.0 where surrogate_id = 2505884.0, parameters: None
# [2023-05-29 02:53:43,635] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:43,640] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 137634.0 where surrogate_id = 2524291.0, parameters: None
# [2023-05-29 02:53:44,642] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:44,644] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 137634.0 where surrogate_id = 2699072.0, parameters: None
# [2023-05-29 02:53:45,683] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:45,685] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 137634.0 where surrogate_id = 2471056.0, parameters: None
# [2023-05-29 02:53:46,708] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:53:46,710] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114104.0 where surrogate_id = 
{sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:24,986] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114202.0 where surrogate_id = 1166474.0, parameters: None
# [2023-05-29 02:54:25,976] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:25,978] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114122.0 where surrogate_id = 1165937.0, parameters: None
# [2023-05-29 02:54:27,065] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:27,068] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113786.0 where surrogate_id = 1162945.0, parameters: None
# [2023-05-29 02:54:28,281] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:28,283] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114138.0 where surrogate_id = 1170406.0, parameters: None
# [2023-05-29 02:54:29,408] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:29,409] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114138.0 where surrogate_id = 1173920.0, parameters: None
# [2023-05-29 02:54:30,944] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:30,946] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114138.0 where surrogate_id = 1175203.0, parameters: None
# [2023-05-29 02:54:32,412] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:32,415] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114138.0 where surrogate_id = 1182036.0, parameters: None
# [2023-05-29 02:54:33,521] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:33,524] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114138.0 where surrogate_id = 1186067.0, parameters: None
# [2023-05-29 02:54:34,522] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:34,524] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114138.0 where surrogate_id = 1172738.0, parameters: None
# [2023-05-29 02:54:35,518] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:35,521] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114138.0 where surrogate_id = 1177565.0, parameters: None
# [2023-05-29 02:54:36,546] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:36,548] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114138.0 where surrogate_id = 1179993.0, parameters: None
# [2023-05-29 02:54:37,549] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:37,552] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114138.0 where surrogate_id = 1176403.0, parameters: None
# [2023-05-29 02:54:38,542] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:38,546] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114138.0 where surrogate_id = 1184427.0, parameters: None
# [2023-05-29 02:54:39,545] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:39,548] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114138.0 where surrogate_id = 1171570.0, parameters: None
# [2023-05-29 02:54:41,032] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:41,034] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114138.0 where surrogate_id = 1178902.0, parameters: None
# [2023-05-29 02:54:42,289] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:42,292] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114138.0 where surrogate_id = 1163736.0, parameters: None
# [2023-05-29 02:54:43,430] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:43,433] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114138.0 where surrogate_id = 1169232.0, parameters: None
# [2023-05-29 02:54:44,455] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:44,458] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1162375.0, parameters: None
# [2023-05-29 02:54:45,997] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:45,998] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113786.0 where surrogate_id = 1165711.0, parameters: None
# [2023-05-29 02:54:47,533] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:47,535] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114077.0 where surrogate_id = 1168483.0, parameters: None
# [2023-05-29 02:54:48,936] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:48,939] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114153.0 where surrogate_id = 1164569.0, parameters: None
# [2023-05-29 02:54:49,926] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:49,928] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113800.0 where surrogate_id = 1163127.0, parameters: None
# [2023-05-29 02:54:50,918] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:50,921] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 109129.0 where surrogate_id = 3275139.0, parameters: None
# [2023-05-29 02:54:51,937] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:51,939] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 109129.0 where surrogate_id = 3369893.0, parameters: None
# [2023-05-29 02:54:52,960] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 02:54:52,963] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 109129.0 where surrogate_id = 3357869.0, parameters: None
# [2023-05-29 02:54:54,076] {sql.py:373} INFO - Rows affected: 1
# ...
# [2023-05-29 03:39:13,246] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:13,249] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113758.0 where surrogate_id = 1174614.0, parameters: None
# [2023-05-29 03:39:14,714] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:14,716] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113758.0 where surrogate_id = 1168630.0, parameters: None
# [2023-05-29 03:39:16,204] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:16,206] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114140.0 where surrogate_id = 1177745.0, parameters: None
# [2023-05-29 03:39:17,210] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:17,212] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114140.0 where surrogate_id = 1176584.0, parameters: None
# [2023-05-29 03:39:18,251] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:18,254] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114140.0 where surrogate_id = 1174104.0, parameters: None
# [2023-05-29 03:39:19,285] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:19,287] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114140.0 where surrogate_id = 1184606.0, parameters: None
# [2023-05-29 03:39:20,348] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:20,350] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114140.0 where surrogate_id = 1179024.0, parameters: None
# [2023-05-29 03:39:21,357] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:21,359] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114140.0 where surrogate_id = 1170597.0, parameters: None
# [2023-05-29 03:39:22,368] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:22,369] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114140.0 where surrogate_id = 1175384.0, parameters: None
# [2023-05-29 03:39:23,459] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:23,460] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114140.0 where surrogate_id = 1164702.0, parameters: None
# [2023-05-29 03:39:24,477] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:24,480] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114140.0 where surrogate_id = 1171760.0, parameters: None
# [2023-05-29 03:39:25,474] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:25,475] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114140.0 where surrogate_id = 1182216.0, parameters: None
# [2023-05-29 03:39:26,471] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:26,474] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114140.0 where surrogate_id = 1186245.0, parameters: None
# [2023-05-29 03:39:27,466] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:27,468] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114140.0 where surrogate_id = 1169424.0, parameters: None
# [2023-05-29 03:39:28,461] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:28,465] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114140.0 where surrogate_id = 1172925.0, parameters: None
# [2023-05-29 03:39:29,460] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:29,461] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114140.0 where surrogate_id = 1180172.0, parameters: None
# [2023-05-29 03:39:30,479] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:30,481] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 173940.0 where surrogate_id = 3342830.0, parameters: None
# [2023-05-29 03:39:31,477] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:31,479] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 173940.0 where surrogate_id = 3338622.0, parameters: None
# [2023-05-29 03:39:32,489] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:32,491] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 173940.0 where surrogate_id = 3262072.0, parameters: None
# [2023-05-29 03:39:33,504] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:33,506] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 137617.0 where surrogate_id = 2504964.0, parameters: None
# [2023-05-29 03:39:34,510] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:34,511] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 137617.0 where surrogate_id = 2501877.0, parameters: None
# [2023-05-29 03:39:35,515] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:35,516] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 137617.0 where surrogate_id = 2471165.0, parameters: None
# [2023-05-29 03:39:36,533] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:36,535] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113786.0 where surrogate_id = 1163378.0, parameters: None
# [2023-05-29 03:39:37,536] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:37,538] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114088.0 where surrogate_id = 1169668.0, parameters: None
# [2023-05-29 03:39:38,549] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:38,551] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114088.0 where surrogate_id = 1166728.0, parameters: None
# [2023-05-29 03:39:42,845] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:42,847] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114182.0 where surrogate_id = 1185083.0, parameters: None
# [2023-05-29 03:39:43,928] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:43,930] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114182.0 where surrogate_id = 1178255.0, parameters: None
# [2023-05-29 03:39:44,951] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:44,952] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114182.0 where surrogate_id = 1180697.0, parameters: None
# [2023-05-29 03:39:45,952] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:45,953] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114182.0 where surrogate_id = 1182708.0, parameters: None
# [2023-05-29 03:39:46,947] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:46,949] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114182.0 where surrogate_id = 1186727.0, parameters: None
# [2023-05-29 03:39:47,947] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:47,948] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114182.0 where surrogate_id = 1172094.0, parameters: None
# [2023-05-29 03:39:48,947] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:48,948] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114182.0 where surrogate_id = 1167840.0, parameters: None
# [2023-05-29 03:39:49,945] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:49,946] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113774.0 where surrogate_id = 1166143.0, parameters: None
# [2023-05-29 03:39:50,943] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:50,944] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113774.0 where surrogate_id = 1179206.0, parameters: None
# [2023-05-29 03:39:52,349] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:52,350] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 100083.0 where surrogate_id = 3264366.0, parameters: None
# [2023-05-29 03:39:53,391] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:53,392] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 100083.0 where surrogate_id = 3342822.0, parameters: None
# [2023-05-29 03:39:54,399] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:54,400] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 100083.0 where surrogate_id = 3262052.0, parameters: None
# [2023-05-29 03:39:55,411] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:55,412] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114101.0 where surrogate_id = 1162567.0, parameters: None
# [2023-05-29 03:39:56,426] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:56,427] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114131.0 where surrogate_id = 1163436.0, parameters: None
# [2023-05-29 03:39:57,432] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:57,433] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113771.0 where surrogate_id = 1176940.0, parameters: None
# [2023-05-29 03:39:58,437] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:58,438] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 113771.0 where surrogate_id = 1167485.0, parameters: None
# [2023-05-29 03:39:59,486] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:39:59,487] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114121.0 where surrogate_id = 1173119.0, parameters: None
# [2023-05-29 03:40:00,512] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:00,513] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114121.0 where surrogate_id = 1166183.0, parameters: None
# [2023-05-29 03:40:01,512] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:01,513] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114121.0 where surrogate_id = 1173580.0, parameters: None
# [2023-05-29 03:40:02,525] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:02,526] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114125.0 where surrogate_id = 1177176.0, parameters: None
# [2023-05-29 03:40:03,519] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:03,520] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1162382.0, parameters: None
# [2023-05-29 03:40:04,550] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:04,551] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114133.0 where surrogate_id = 1169972.0, parameters: None
# [2023-05-29 03:40:05,550] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:05,551] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 151709.0 where surrogate_id = 3342835.0, parameters: None
# [2023-05-29 03:40:06,545] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:06,546] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 151709.0 where surrogate_id = 3315565.0, parameters: None
# [2023-05-29 03:40:07,552] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:07,554] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 151709.0 where surrogate_id = 3262094.0, parameters: None
# [2023-05-29 03:40:08,557] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:08,558] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 110653.0 where surrogate_id = 3573416.0, parameters: None
# [2023-05-29 03:40:09,949] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:09,950] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 110653.0 where surrogate_id = 3558763.0, parameters: None
# [2023-05-29 03:40:10,959] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:10,960] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 110653.0 where surrogate_id = 3561328.0, parameters: None
# [2023-05-29 03:40:11,979] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:11,980] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 110653.0 where surrogate_id = 3545682.0, parameters: None
# [2023-05-29 03:40:12,988] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:12,989] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 110653.0 where surrogate_id = 3275143.0, parameters: None
# [2023-05-29 03:40:14,050] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:14,051] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 110653.0 where surrogate_id = 3549144.0, parameters: None
# [2023-05-29 03:40:15,058] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:15,059] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 110653.0 where surrogate_id = 3534432.0, parameters: None
# [2023-05-29 03:40:16,071] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:16,072] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 105140.0 where surrogate_id = 3522083.0, parameters: None
# [2023-05-29 03:40:17,074] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:17,075] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 105140.0 where surrogate_id = 3521610.0, parameters: None
# [2023-05-29 03:40:18,168] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:18,171] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 105140.0 where surrogate_id = 3262077.0, parameters: None
# [2023-05-29 03:40:19,163] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:19,164] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 105140.0 where surrogate_id = 3519482.0, parameters: None
# [2023-05-29 03:40:20,355] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:20,356] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114159.0 where surrogate_id = 1164977.0, parameters: None
# [2023-05-29 03:40:21,602] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:21,603] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 114196.0 where surrogate_id = 1162388.0, parameters: None
# [2023-05-29 03:40:22,681] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:22,682] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 185909.0 where surrogate_id = 3172300.0, parameters: None
# [2023-05-29 03:40:23,692] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:23,693] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 185909.0 where surrogate_id = 3704253.0, parameters: None
# [2023-05-29 03:40:24,687] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:24,689] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 185909.0 where surrogate_id = 3078199.0, parameters: None
# [2023-05-29 03:40:25,685] {sql.py:373} INFO - Rows affected: 1
# [2023-05-29 03:40:25,687] {sql.py:364} INFO - Running statement: update bloomlive.loans_fact_table set client_key = 185909.0 where surrogate_id = 3175828.0, parameters: None
# [2023-05-29 03:40:26,682] {sql.py:373} INFO - Rows affected: 1

# %%
with open('/home/henrykuria/data/client_key_updates_bloomlive_loans_fact_table.sql', 'w+') as f:
    for update in updates:
        f.write(f'{update}; \n')
